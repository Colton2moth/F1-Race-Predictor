# %%
import fastf1
import pandas as pd
import numpy as np
import os


cache_path = '../cache'


os.makedirs(cache_path, exist_ok=True) 


fastf1.Cache.enable_cache(cache_path)


print("Loading sessions...")

fp1 = fastf1.get_session(2023, 'Australian Grand Prix', 'FP1')
fp2 = fastf1.get_session(2023, 'Australian Grand Prix', 'FP2')
fp3 = fastf1.get_session(2023, 'Australian Grand Prix', 'FP3')
quali = fastf1.get_session(2023, 'Australian Grand Prix', 'Q')
race = fastf1.get_session(2023, 'Australian Grand Prix', 'R')

fp1.load()
fp2.load()
fp3.load()
quali.load()
race.load()
# Out:
# Loading sessions...
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '4', '10', '11', '14', '16', '18', '20', '21', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Australian Grand Prix - Practice 2 [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 2
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 2)
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '4', '10', '11', '14', '16', '18', '20', '21', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Australian Grand Prix - Practice 3 [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '4', '10', '11', '14', '16', '18', '20', '21', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '63', '44', '14', '55', '18', '16', '23', '10', '27', '31', '22', '4', '20', '21', '81', '24', '2', '77', '11']
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '44', '14', '18', '11', '4', '27', '81', '24', '22', '77', '55', '10', '31', '21', '2', '20', '63', '23', '16']

# %%
# Get the fastest lap for each driver in each session
fp1_fastest = fp1.laps.groupby('DriverNumber')['LapTime'].min()
fp2_fastest = fp2.laps.groupby('DriverNumber')['LapTime'].min()
fp3_fastest = fp3.laps.groupby('DriverNumber')['LapTime'].min()
quali_fastest = quali.laps.groupby('DriverNumber')['LapTime'].min()

# Let's look at the data from FP1 to see what it looks like
print("--- FP1 Fastest Laps ---")
display(fp1_fastest)

print("--- FP2 Fastest Laps ---")
display(fp2_fastest)

print("--- FP3 Fastest Laps ---")
display(fp3_fastest)

print("\n--- Qualifying Fastest Laps ---")
display(quali_fastest)
# Out:
# --- FP1 Fastest Laps ---
# DriverNumber
# 1    0 days 00:01:18.790000
# 10   0 days 00:01:19.646000
# 11   0 days 00:01:19.293000
# 14   0 days 00:01:19.317000
# 16   0 days 00:01:19.378000
# 18   0 days 00:01:19.766000
# 2    0 days 00:01:20.074000
# 20   0 days 00:01:21.147000
# 21   0 days 00:01:19.933000
# 22   0 days 00:01:20.399000
# 23   0 days 00:01:19.766000
# 24   0 days 00:01:20.569000
# 27   0 days 00:01:19.806000
# 31   0 days 00:01:20.175000
# 4    0 days 00:01:19.536000
# 44   0 days 00:01:19.223000
# 55   0 days 00:01:19.505000
# 63   0 days 00:01:19.699000
# 77   0 days 00:01:20.419000
# 81   0 days 00:01:19.777000
# Name: LapTime, dtype: timedelta64[ns]
# --- FP2 Fastest Laps ---
# DriverNumber
# 1    0 days 00:01:19.502000
# 10   0 days 00:01:20.206000
# 11   0 days 00:01:20.083000
# 14   0 days 00:01:18.887000
# 16   0 days 00:01:19.332000
# 18   0 days 00:01:20.579000
# 20   0 days 00:01:21.266000
# 21   0 days 00:01:20.600000
# 22   0 days 00:01:20.220000
# 23   0 days 00:01:21.182000
# 24   0 days 00:01:20.470000
# 27   0 days 00:01:20.194000
# 31   0 days 00:01:19.725000
# 4    0 days 00:01:20.176000
# 44   0 days 00:01:20.323000
# 55   0 days 00:01:19.695000
# 63   0 days 00:01:19.672000
# 77   0 days 00:01:20.312000
# 81   0 days 00:01:20.380000
# Name: LapTime, dtype: timedelta64[ns]
# --- FP3 Fastest Laps ---
# DriverNumber
# 1    0 days 00:01:17.565000
# 10   0 days 00:01:18.094000
# 11   0 days 00:01:18.123000
# 14   0 days 00:01:17.727000
# 16   0 days 00:01:18.691000
# 18   0 days 00:01:18.198000
# 2    0 days 00:01:18.947000
# 20   0 days 00:01:19.056000
# 21   0 days 00:01:19.092000
# 22   0 days 00:01:18.901000
# 23   0 days 00:01:18.553000
# 24   0 days 00:01:18.330000
# 27   0 days 00:01:18.410000
# 31   0 days 00:01:17.938000
# 4    0 days 00:01:19.146000
# 44   0 days 00:01:18.138000
# 55   0 days 00:01:18.127000
# 63   0 days 00:01:17.955000
# 77   0 days 00:01:18.809000
# 81   0 days 00:01:18.713000
# Name: LapTime, dtype: timedelta64[ns]
# --- Qualifying Fastest Laps ---
# DriverNumber
# 1    0 days 00:01:16.732000
# 10   0 days 00:01:17.574000
# 11   0 days 00:01:40.187000
# 14   0 days 00:01:17.139000
# 16   0 days 00:01:17.369000
# 18   0 days 00:01:17.308000
# 2    0 days 00:01:18.557000
# 20   0 days 00:01:18.129000
# 21   0 days 00:01:18.335000
# 22   0 days 00:01:18.099000
# 23   0 days 00:01:17.609000
# 24   0 days 00:01:18.540000
# 27   0 days 00:01:17.412000
# 31   0 days 00:01:17.768000
# 4    0 days 00:01:18.119000
# 44   0 days 00:01:17.104000
# 55   0 days 00:01:17.270000
# 63   0 days 00:01:16.968000
# 77   0 days 00:01:18.714000
# 81   0 days 00:01:18.517000
# Name: LapTime, dtype: timedelta64[ns]

# %%
race_results = race.results
race_results['Podium_finish'] = race_results['Position'] <= 3
podium_info = race_results[['DriverNumber','Position', 'Podium_finish']]


print("--- Race Results and Podium Finishers ---")
display(podium_info.reset_index(drop=True))
# Out:
# --- Race Results and Podium Finishers ---
#    DriverNumber  Position  Podium_finish
# 0             1       1.0           True
# 1            44       2.0           True
# 2            14       3.0           True
# 3            18       4.0          False
# 4            11       5.0          False
# 5             4       6.0          False
# 6            27       7.0          False
# 7            81       8.0          False
# 8            24       9.0          False
# 9            22      10.0          False
# 10           77      11.0          False
# 11           55      12.0          False
# 12           10      13.0          False
# 13           31      14.0          False
# 14           21      15.0          False
# 15            2      16.0          False
# 16           20      17.0          False
# 17           63      18.0          False
# 18           23      19.0          False
# 19           16      20.0          False
